# %% [markdown]
# # Homework 1. Exploratory Data Analysis
#
# Due: Thursday, September 18, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW1.ipynb download=HW1.ipynb> Download this assignment</a>
#
# ---

# %% [markdown]
# ## Introduction
#
# In this homework we ask you three questions that we expect you to answer using data. For each question we ask you to complete a series of tasks that should help guide you through the data analysis. Complete these tasks and then write a short (100 words or less) answer to the question.
#
# **Note**: We will briefly discuss this homework assignment on Thursday in class.
#
# #### Data
# For this assignment we will use two databases:
#
# 1. The [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics) which contains the "complete batting and pitching statistics from 1871 to 2013, plus fielding statistics, standings, team stats, managerial records, post-season data, and more. For more details on the latest release, please [read the documentation](http://seanlahman.com/files/database/readme2012.txt)."
#
# 2. [Gapminder](http://www.gapminder.org) is a great resource that contains over [500 data sets](http://www.gapminder.org/data/) related to world indicators such as income, GDP and life expectancy.
#
#
# #### Purpose
#
# In this assignment, you will learn how to:
#
# a. Load in CSV files from the web.
#
# b. Create functions in python.
#
# C. Create plots and summary statistics for exploratory data analysis such as histograms, boxplots and scatter plots.
#
#
# #### Useful libraries for this assignment
#
# * [numpy](http://docs.scipy.org/doc/numpy-dev/user/index.html), for arrays
# * [pandas](http://pandas.pydata.org/), for data frames
# * [matplotlib](http://matplotlib.org/), for plotting
#
# ---

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Problem 1
#
# In Lecture 1, we showed a plot that provided evidence that the 2002 and 2003 Oakland A's, a team that used data science, had a competitive advantage. Since, others teams have started using data science as well. Use exploratory data analysis to determine if the competitive advantage has since disappeared.

# %% [markdown]
# #### Problem 1(a)
# Load in [these CSV files](http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip) from the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics). For this assignment, we will use the 'Salaries.csv' and 'Teams.csv' tables. Read these tables into a pandas `DataFrame` and show the head of each table.
#
# **Hint** Use the [requests](http://docs.python-requests.org/en/latest/), [StringIO](http://docs.python.org/2/library/stringio.html) and [zipfile](https://docs.python.org/2/library/zipfile.html) modules to get from the web.

# %%
#your code here
df_salaries = pd.read_csv("data/Salaries.csv")
df_teams = pd.read_csv("data/Teams.csv")

df_salaries.head()
# Out:
#    yearID teamID lgID   playerID   salary
# 0    1985    BAL   AL  murraed02  1472819
# 1    1985    BAL   AL   lynnfr01  1090000
# 2    1985    BAL   AL  ripkeca01   800000
# 3    1985    BAL   AL   lacyle01   725000
# 4    1985    BAL   AL  flanami01   641667

# %% [markdown]
# #### Problem 1(b)
#
# Summarize the Salaries DataFrame to show the total salaries for each team for each year. Show the head of the new summarized DataFrame.

# %%
#your code here
df_salaries_summarize = df_salaries.groupby([df_salaries.teamID,df_salaries.yearID],as_index=False).sum()
df_salaries_summarize.head()
# Out:
#   teamID  yearID    salary
# 0    ANA    1997  31135472
# 1    ANA    1998  41281000
# 2    ANA    1999  55388166
# 3    ANA    2000  51464167
# 4    ANA    2001  47535167

# %% [markdown]
# #### Problem 1(c)
#
# Merge the new summarized Salaries DataFrame and Teams DataFrame together to create a new DataFrame
# showing wins and total salaries for each team for each year year. Show the head of the new merged DataFrame.
#
# **Hint**: Merge the DataFrames using `teamID` and `yearID`.

# %%
df_merged = pd.merge(df_salaries_summarize,df_teams, how="inner",on=['teamID','yearID'])

df_merged= df_merged[['salary','yearID','teamID','W']]
df_merged.head()
# Out:
#      salary  yearID teamID   W
# 0  31135472    1997    ANA  84
# 1  41281000    1998    ANA  85
# 2  55388166    1999    ANA  70
# 3  51464167    2000    ANA  82
# 4  47535167    2001    ANA  75

# %% [markdown]
# #### Problem 1(d)
#
# How would you graphically display the relationship between total wins and total salaries for a given year? What kind of plot would be best? Choose a plot to show this relationship and specifically annotate the Oakland baseball team on the on the plot. Show this plot across multiple years. In which years can you detect a competitive advantage from the Oakland baseball team of using data science? When did this end?
#
# **Hints**: Use a `for` loop to consider multiple years. Use the `teamID` (three letter representation of the team name) to save space on the plot.

# %%
#your code here
def plot_win_salaries_per_year(year,n):
    
    plt.subplot(5,5 ,n)
        
    df_merged_per_year = df_merged[df_merged.yearID==year]
    
    plt.plot(df_merged.W,df_merged.salary, 'o',markersize=2,color='r')
    #plt.axis([0,3,0,df_merged_per_year.salary.max()])
    
    oakland_row = df_merged_per_year[df_merged_per_year.teamID == "OAK"]
    
    if oakland_row.W.size>0:
        
        oakland_x = oakland_row.W.iloc[0]
        oakland_y = oakland_row.salary.iloc[0]

         
        if year%2==0:
            oakland_x_text = oakland_x+.2
           
        else:
            oakland_x_text = oakland_x-.2
            
        oakland_point = (oakland_x,oakland_y)
        
            
        plt.plot(oakland_point[0],oakland_point[1],'o',markersize=10)
        plt.annotate(str(year),xy=oakland_point)

# %%
plt.figure(figsize=(20,20))
for n,year in enumerate(range(1999,2014)):
    plot_win_salaries_per_year(year,n+1)

# %% [markdown]
# #### Problem 1(e):
#
# **For AC209 Students**: Fit a linear regression to the data from each year and obtain the residuals. Plot the residuals against time to detect patterns that support your answer in 1(d).

# %%
df_simplified = df_merged[['salary','yearID']]
df_simplified.head()
# Out:
#      salary  yearID
# 0  31135472    1997
# 1  41281000    1998
# 2  55388166    1999
# 3  51464167    2000
# 4  47535167    2001

# %%
df_simplified.corr()
# Out:
#           salary    yearID
# salary  1.000000  0.759888
# yearID  0.759888  1.000000

# %%
#your code here
def plot_linear_regression(dataframe):
    data = np.asarray(dataframe)
    
    lr = LinearRegression()
    X, y = data[:, 1:], data[:, 0]
    
    print lr.fit(X, y)
    range_win = np.arange(1983,2015,1)
    range_win = range_win.reshape(-1,1)
    
    result = lr.predict(range_win)
    #print linear regression line
    from sklearn.metrics import r2_score
    print "y.shape",y.shape
    prediction = lr.predict(X)
    print "prediction.shape",prediction.shape
    
    print "r2 score :",r2_score(y, prediction, multioutput='variance_weighted')  
    
    print lr.coef_
    print lr.intercept_
   
    plt.plot(data[:, 1:], data[:, 0],'o')
    plt.plot(range_win,result, color="r")

# %%
plot_linear_regression(df_simplified)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# y.shape (828,)
# prediction.shape (828,)
# r2 score : 0.577430108545
# [ 3545386.54589279]
# -7034897422.84

# %% [markdown]
# ### Residual Plot

# %%
def plot_residual(dataframe):
    data = np.asarray(dataframe)
    X,y = data[:,1:], data[:,0]
   
    
    lr = LinearRegression()
    lr.fit(X,y)
    print lr.intercept_
    print lr.coef_
    print lr.score(X,y)
 
    plt.plot(X,y-lr.predict(X),'o')

# %%
plot_residual(df_simplified)
# Out:
# -7034897422.84
# [ 3545386.54589279]
# 0.577430108545

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 2
#
# Several media reports have demonstrated the income inequality has increased in the US during this last decade. Here we will look at global data. Use exploratory data analysis to determine if the gap between Africa/Latin America/Asia and Europe/NorthAmerica has increased, decreased or stayed the same during the last two decades.

# %% [markdown]
# #### Problem 2(a)
#
# Using the list of countries by continent from [World Atlas](http://www.worldatlas.com/cntycont.htm) data, load in the `countries.csv` file into a pandas DataFrame and name this data set as `countries`.  This data set can be found on Github in the 2014_data repository [here](https://github.com/cs109/2014_data/blob/master/countries.csv).

# %%
#your code here
df_countries = pd.read_csv("../../2014_data/countries.csv")
df_countries.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# Using the [data available on Gapminder](http://www.gapminder.org/data/), load in the [Income per person (GDP/capita, PPP$ inflation-adjusted)](https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0) as a pandas DataFrame and name this data set as `income`.
#
# **Hint**: Consider using the pandas function `pandas.read_excel()` to read in the .xlsx file directly.

# %%
#your code here
df_incomes = pd.read_excel("data/indicator gapminder gdp_per_capita_ppp.xlsx")
df_incomes.head()
# Out:
#           GDP per capita   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  603.0  603.0  603.0  603.0  603.0  603.0  603.0
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  667.0  667.0  668.0  668.0  668.0  668.0  668.0
# 4                Algeria  716.0  716.0  717.0  718.0  719.0  720.0  721.0
#
#     1807   1808   ...        2006     2007     2008     2009     2010  \
# 0    NaN    NaN   ...         NaN      NaN      NaN      NaN      NaN
# 1  603.0  603.0   ...      1173.0   1298.0   1311.0   1548.0   1637.0
# 2    NaN    NaN   ...         NaN      NaN      NaN      NaN      NaN
# 3  668.0  668.0   ...      7476.0   7977.0   8644.0   8994.0   9374.0
# 4  722.0  723.0   ...     12088.0  12289.0  12314.0  12285.0  12494.0
#
#       2011     2012     2013     2014     2015
# 0      NaN      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# Transform the data set to have years as the rows and countries as the columns. Show the head of this data set when it is loaded.

# %%
df_incomes_country_as_index=df_incomes.set_index('GDP per capita')
df_incomes_country_as_index.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# GDP per capita
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            603.0  603.0  603.0  603.0  603.0  603.0  603.0  603.0
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                667.0  667.0  668.0  668.0  668.0  668.0  668.0  668.0
# Algeria                716.0  716.0  717.0  718.0  719.0  720.0  721.0  722.0
#
#                         1808   1809   ...        2006     2007     2008  \
# GDP per capita                        ...
# Abkhazia                 NaN    NaN   ...         NaN      NaN      NaN
# Afghanistan            603.0  603.0   ...      1173.0   1298.0   1311.0
# Akrotiri and Dhekelia    NaN    NaN   ...         NaN      NaN      NaN
# Albania                668.0  668.0   ...      7476.0   7977.0   8644.0
# Algeria                723.0  724.0   ...     12088.0  12289.0  12314.0
#
# ...

# %%
#your code here

df_incomes_country_as_index = df_incomes_country_as_index.T
df_incomes_country_as_index.tail()
# Out:
# GDP per capita  Abkhazia  Afghanistan  Akrotiri and Dhekelia  Albania  \
# 2011                 NaN       1695.0                    NaN   9640.0
# 2012                 NaN       1893.0                    NaN   9811.0
# 2013                 NaN       1884.0                    NaN   9961.0
# 2014                 NaN       1877.0                    NaN  10160.0
# 2015                 NaN       1925.0                    NaN  10620.0
#
# GDP per capita  Algeria  American Samoa  Andorra  Angola  Anguilla  \
# 2011            12606.0             NaN  41958.0  7094.0       NaN
# 2012            12779.0             NaN  41926.0  7230.0       NaN
# 2013            12893.0             NaN  43735.0  7488.0       NaN
# 2014            13179.0             NaN  44929.0  7546.0       NaN
# 2015            13434.0             NaN  46577.0  7615.0       NaN
#
# GDP per capita  Antigua and Barbuda   ...     North Yemen (former)  \
# 2011                        19988.0   ...                      NaN
# ...

# %% [markdown]
# #### Problem 2(b)
#
# Graphically display the distribution of income per person across all countries in the world for any given year (e.g. 2000).  What kind of plot would be best?

# %%
#your code here
df_plot2b =df_incomes_country_as_index.ix[2012]
df_plot2b = df_plot2b[df_plot2b>0]
df_plot2b=df_plot2b.sort_values()
df_plot2b[:10].plot(kind="bar")
#df_plot2b[-10:].plot(kind="bar")

# %% [markdown]
# #### Problem 2(c)
#
# Write a function to merge the `countries` and `income` data sets for any given year.

# %%
"""
Function
--------
mergeByYear

Return a merged DataFrame containing the income, 
country name and region for a given year. 

Parameters
----------
year : int
    The year of interest

Returns
-------
a DataFrame
   A pandas DataFrame with three columns titled 
   'Country', 'Region', and 'Income'. 

Example
-------
>>> mergeByYear(2010)
"""
#your code here
def mergeByYear(year):
    df_per_year = df_incomes[['GDP per capita',year]]
    df_per_year = df_per_year.rename(columns={'GDP per capita':'Country'})
    df_per_year = df_per_year.rename(columns={year:'Income'})
    df_mergedCountries = pd.merge(df_countries,df_per_year, on=['Country'])
    #df_mergedCountries=df_mergedCountries.set_index('Region')
    
    return df_mergedCountries

# %%
years = range(1950,2013,10)
for year in (years):
    
    df_mergedCountries =mergeByYear(year)
    df_mergedCountries.Income = np.log10(df_mergedCountries.Income)
    df_mergedCountries.boxplot('Income',by='Region')
    plt.title(year)

# %% [markdown]
# #### Problem 2(d)
#
# Use exploratory data analysis tools such as histograms and boxplots to explore the distribution of the income per person by region data set from 2(c) for a given year. Describe how these change through the recent years?
#
# **Hint**: Use a `for` loop to consider multiple years.

# %% [markdown]
# ## Discussion for Problem 2
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 3
#
# In general, if group A has larger values than group B on average, does this mean the largest values are from group A? Discuss after completing each of the problems below.

# %% [markdown]
# #### Problem 3(a)
#
# Assume you have two list of numbers, X and Y, with distribution approximately normal. X and Y have standard deviation equal to 1, but the average of X is different from the average of Y.  If the difference in the average of X and the average of Y is larger than 0, how does the proportion of X > a compare to the proportion of Y > a?

# %% [markdown]
# Write a function that analytically calculates the ratio of these two proportions: Pr(X > a)/Pr(Y > a) as function of the difference in the average of X and the average of Y.
#
# **Hint**: Use the `scipy.stats` module for useful functions related to a normal random variable such as the probability density function, cumulative distribution function and survival function.
#
# **Update**: Assume Y is normally distributed with mean equal to 0.

# %% [markdown]
# Show the curve for different values of a (a = 2,3,4 and 5).

# %%
"""
Function
--------
ratioNormals

Return ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a) as function of 
    the difference in the average of X 
    and the average of Y. 

Parameters
----------
diff : difference in the average of X 
    and the average of Y. 
a : cutoff value

Returns
-------
Returns ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a)
    
Example
-------
>>> ratioNormals(diff = 1, a = 2)
"""
#your code here
from scipy.stats import norm
def rationNormals(diff,a):
    locX = diff
    pX_a = norm.sf(a,loc=locX,scale=1)
    pY_a = norm.sf(a,loc=0,scale =1)
    return pX_a/pY_a

# %%
#your code here
#print the curve for different value of diff:
diffs = np.linspace(0,5,50)
a_values = range(2,6)

print rationNormals(1,2)


for a in a_values:
    ratios = [rationNormals(diff,a) for diff in diffs]
    plt.plot(diffs,ratios)
    plt.yscale('log')
# Out:
# 6.97381686809

# %% [markdown]
# #### Problem 3(b)
#
# Now consider the distribution of income per person from two regions: Asia and South America. Estimate the average income per person across the countries in those two regions. Which region has the larger average of income per person across the countries in that region?
#
# **Update**: Use the year 2012.

# %%
#your code here
df_income_per_country_region = mergeByYear(2012)
df_income_per_country_region.head()
df_average_income_per_region = df_income_per_country_region.groupby('Region').mean()
df_average_income_per_region.sort_values(by='Income')
# Out:
#                      Income
# Region
# AFRICA          5601.220000
# OCEANIA        10481.153846
# SOUTH AMERICA  13015.750000
# NORTH AMERICA  16036.650000
# ASIA           23500.432432
# EUROPE         30492.720930

# %% [markdown]
# #### Problem 3(c)
#
# Calculate the proportion of countries with income per person that is greater than 10,000 dollars. Which region has a larger proportion of countries with income per person greater than 10,000 dollars? If the answer here is different from the answer in 3(b), explain why in light of your answer to 3(a).
#
# **Update**: Use the year 2012.

# %%
#your code here
df = mergeByYear(2012)
df['>10000 USD']= df.Income>10000
df = df.groupby(['Region','>10000 USD']).count()
del df['Income']
df=df.unstack('>10000 USD')
df.columns = df.columns.droplevel()
df = df.rename(columns={'False':'poor'})
df['rich_poor'] = (df.ix[:,1]/(df.ix[:,1]+df.ix[:,0])*100)
df =df.round({'rich_poor':2})
result = df[['rich_poor']]
result
# Out:
# >10000 USD     rich_poor
# Region
# AFRICA             20.00
# ASIA               56.76
# EUROPE             84.09
# NORTH AMERICA      65.00
# OCEANIA            30.77
# SOUTH AMERICA      75.00

# %%
df = mergeByYear(2012)
df = df[df.Region=='EUROPE']
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9ae9ca5f90>]], dtype=object)

# %% [markdown]
# #### Problem 3(d)
#
# **For AC209 Students**: Re-run this analysis in Problem 3 but compute the average income per person for each region, instead of the average of the reported incomes per person across countries in the region. Why are these two different? Hint: use this [data set](https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&gid=0).

# %%
#your code here
import StringIO
import requests
population_link = 'https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&output=xls'
source = StringIO.StringIO(requests.get(population_link).content)
df_pop = pd.read_excel(source, sheetname = "Data")
df_pop.head()
# Out:
#         Total population       1800       1810       1820       1830  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania   410445.0   423591.0   438671.0   457234.0
# 4                Algeria  2503218.0  2595056.0  2713079.0  2880355.0
#
#         1840       1850       1860       1870       1880     ...      \
# 0        NaN        NaN        NaN        NaN        NaN     ...
# 1  3625022.0  3810047.0  3973968.0  4169690.0  4419695.0     ...
# 2        NaN        NaN        NaN        NaN        NaN     ...
# 3   478227.0   506889.0   552800.0   610036.0   672544.0     ...
# 4  3082721.0  3299305.0  3536468.0  3811028.0  4143163.0     ...
#
#          2006        2007        2008        2009        2010        2011  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
#join population with income per year
incomes2012 = mergeByYear(2012)
incomes2012.head()
# Out:
#     Country  Region   Income
# 0   Algeria  AFRICA  12779.0
# 1    Angola  AFRICA   7230.0
# 2     Benin  AFRICA   1685.0
# 3  Botswana  AFRICA  14905.0
# 4   Burundi  AFRICA    737.0

# %%
def mergeByPopYear(year):
    df_pop_copy  = df_pop.copy()
    df_pop_copy = df_pop_copy.rename(columns={'Total population':'Country'})
    df_pop_copy= df_pop_copy[['Country',2012]]
    df_pop_copy= df_pop_copy.rename(columns={year:'Population'})
    return df_pop_copy

# %%
def mean_on_pop(year):
    pop_gdp = pd.merge(mergeByPopYear(year),mergeByYear(year), on=['Country'])
    pop_gdp['Total Incomes'] = pop_gdp.Population*pop_gdp.Income
    return pop_gdp

# %%
# comp
result = mean_on_pop(2012)
result.sort_values(by='Total Incomes',ascending=False)
result['% >10000'] = resul
result
# Out:
#                     Country   Population         Region   Income  \
# 0               Afghanistan   29726803.0           ASIA   1893.0
# 1                   Albania    2880667.0         EUROPE   9811.0
# 2                   Algeria   37439427.0         AFRICA  12779.0
# 3                   Andorra      79316.0         EUROPE  41926.0
# 4                    Angola   22685632.0         AFRICA   7230.0
# 5       Antigua and Barbuda      89069.0  NORTH AMERICA  20577.0
# 6                 Argentina   42095224.0  SOUTH AMERICA  17101.0
# 7                   Armenia    2978339.0         EUROPE   7291.0
# 8                 Australia   22911375.0        OCEANIA  42522.0
# 9                   Austria    8455477.0         EUROPE  44216.0
# 10               Azerbaijan    9361477.0         EUROPE  15888.0
# 11                  Bahamas     372388.0  NORTH AMERICA  22841.0
# 12                  Bahrain    1333577.0           ASIA  40732.0
# ...

# %%
result = result.groupby('Region').sum()
result.head()
result['Per Head'] = result['Total Incomes']/ result.Population
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-224c25645b80> in <module>()
# ----> 1 result = result.groupby('Region').sum()
#       2 result.head()
#       3 result['Per Head'] = result['Total Incomes']/ result.Population
#
# /home/ramon/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3746         axis = self._get_axis_number(axis)
#    3747         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3748                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3749
#    3750     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /home/ramon/anaconda2/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1426         raise TypeError('invalid type: %s' % type(obj))
#    1427
# ...

# %% [markdown]
# ## Discussion for Problem 3
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---
