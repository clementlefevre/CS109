# %%
# %matplotlib inline

from sqlalchemy import create_engine
import datetime
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as col
from matplotlib.dates import  DateFormatter
import seaborn as sns

import config
import db_service
import data_preparation
import weather_service

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)

sns.set_style("whitegrid")
sns.set_context("poster")

from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble.forest import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import linear_model
from sklearn.grid_search import GridSearchCV

from tpot import TPOTRegressor
from sklearn.model_selection import train_test_split


from sklearn.ensemble import RandomForestRegressor, VotingClassifier
from sklearn.linear_model import LassoLarsCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, make_union
from sklearn.preprocessing import FunctionTransformer, MaxAbsScaler

np.set_printoptions(precision=3,suppress=True)
# Out:
# /home/ramon/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/ramon/anaconda2/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
### Call this method to retrieve the data directly from DB :

# db_service.create_counts_sites_weather_holidays_day()

### Otherwise load the file :
df = pd.read_csv('data/counts_sites_weather_holidays_day.csv',parse_dates=['date'],index_col=0)


dataset_past_dict = {}
dataset_forecasts_dict ={}

# %% [markdown]
# ### Data preparation

# %%
# df_forecasting = data_preparation.create_forecasting_data(datetime.date(2016,10,2),datetime.date(2016,10,10))

# %%
df_past = df[df.date<datetime.date(2016,9,25)]
site = 3

# %%
data_past_reg = data_preparation.regularize_dataset(df_past)
data_preparation.create_predictors_and_target(data_past_reg,dataset_past_dict)

df_forecasts = data_preparation.create_forecasts_data(datetime.date(2016,10,14),datetime.date(2016,10,17))
df_forecasts = data_preparation.regularize_forecast(df_forecasts,dataset_past_dict)
data_preparation.create_predictors_and_target(df_forecasts,dataset_forecasts_dict, forecasting=True)

# %%
X = dataset_past_dict[site]['X'].values
y = dataset_past_dict[site]['y'].values
fields = dataset_past_dict[site]['X'].columns[3:].tolist()

X_forecast = dataset_forecasts_dict[site]['X'].values

# %% [markdown]
# ### Pipeline

# %%
def cv_optimize(clf, parameters, X, y, n_jobs=1, n_folds=5, score_func=None):
    if score_func:
        gs = GridSearchCV(clf, param_grid=parameters, cv=n_folds, n_jobs=n_jobs, scoring=score_func)
    else:
        gs = GridSearchCV(clf, param_grid=parameters, n_jobs=n_jobs, cv=n_folds)
    gs.fit(X, y)
    print "BEST", gs.best_params_, gs.best_score_, gs.grid_scores_
    best = gs.best_estimator_
    return best

# %%
def do_classify(clf, parameters, X,y, mask=None, score_func=None, n_folds=5, n_jobs=1):
    # remove index and idbldsite
    X,y = X[:,3:],y[:,2:].ravel()
    Xtrain, Xtest, ytrain, ytest = train_test_split(X,y,test_size=0.8)
    clf = cv_optimize(clf, parameters, Xtrain, ytrain, n_jobs=n_jobs, n_folds=n_folds, score_func=score_func)
    clf=clf.fit(Xtrain, ytrain)
    training_accuracy = clf.score(Xtrain, ytrain)
    test_accuracy = clf.score(Xtest, ytest)
    
    print "############# based on standard predict ################"
    print "Accuracy on training data: %0.2f" % (training_accuracy)
    print "Accuracy on test data:     %0.2f" % (test_accuracy)
    print "########################################################"
    try:
        print pd.DataFrame(zip(clf.feature_importances_,fields))
    except :
        print "no feature_importance"
    print "########################################################"
    return clf, Xtrain, ytrain, Xtest, ytest

# %% [markdown]
# #### RandomForestRegressor

# %%
params = { 'n_estimators':[20,30,50,300],'bootstrap':[True], 'criterion':['mse']}

# %%
clf_rdm = RandomForestRegressor()

# %%
clf_rdm, Xtrain, ytrain, Xtest, ytest = do_classify(clf_rdm,params,X,y)
# Out:
# BEST {'n_estimators': 300, 'bootstrap': True, 'criterion': 'mse'} 0.485534935285 [mean: 0.45839, std: 0.14182, params: {'n_estimators': 20, 'bootstrap': True, 'criterion': 'mse'}, mean: 0.47999, std: 0.09990, params: {'n_estimators': 30, 'bootstrap': True, 'criterion': 'mse'}, mean: 0.45416, std: 0.13775, params: {'n_estimators': 50, 'bootstrap': True, 'criterion': 'mse'}, mean: 0.48553, std: 0.13040, params: {'n_estimators': 300, 'bootstrap': True, 'criterion': 'mse'}]
# ############# based on standard predict ################
# Accuracy on training data: 0.93
# Accuracy on test data:     0.66
# ########################################################
#            0                     1
# 0   0.000000           not_holiday
# 1   0.019775                 day_0
# 2   0.014173                 day_1
# 3   0.026297                 day_2
# 4   0.024635                 day_3
# 5   0.029039                 day_4
# 6   0.017745                 day_5
# 7   0.519633                 day_6
# 8   0.008945               month_1
# 9   0.001031               month_2
# 10  0.010941               month_3
# 11  0.000455               month_4
# 12  0.013733               month_5
# 13  0.004022               month_6
# 14  0.007708               month_7
# 15  0.007653               month_8
# 16  0.001129               month_9
# 17  0.002376              month_10
# 18  0.000632              month_11
# 19  0.055210              month_12
# 20  0.080645    mintemperature_reg
# 21  0.064764    maxtemperature_reg
# 22  0.033420       cloudamount_reg
# 23  0.056038  weathersituation_reg
# ########################################################

# %%
# clf_rdm.score(X_forecast[:,3:],y_forecast[:,2:])

# %% [markdown]
# #### GradientBoostingRegressor

# %%
clf_gbr = GradientBoostingRegressor()
params = {'loss' : ['ls', 'lad', 'huber', 'quantile']}

clf_gbr, Xtrain, ytrain, Xtest, ytest = do_classify(clf_gbr,params,X,y)
print clf_gbr.score(Xtest,ytest)
# Out:
# BEST {'loss': 'lad'} 0.652948414086 [mean: 0.61675, std: 0.16418, params: {'loss': 'ls'}, mean: 0.65295, std: 0.16980, params: {'loss': 'lad'}, mean: 0.62409, std: 0.22322, params: {'loss': 'huber'}, mean: -0.29697, std: 0.25370, params: {'loss': 'quantile'}]
# ############# based on standard predict ################
# Accuracy on training data: 0.87
# Accuracy on test data:     0.65
# ########################################################
#            0                     1
# 0   0.000000           not_holiday
# 1   0.013394                 day_0
# 2   0.018980                 day_1
# 3   0.050538                 day_2
# 4   0.029525                 day_3
# 5   0.043830                 day_4
# 6   0.049001                 day_5
# 7   0.137219                 day_6
# 8   0.001873               month_1
# 9   0.000941               month_2
# 10  0.005911               month_3
# 11  0.003269               month_4
# 12  0.000000               month_5
# 13  0.008317               month_6
# 14  0.045477               month_7
# 15  0.001220               month_8
# 16  0.036394               month_9
# 17  0.007951              month_10
# 18  0.017337              month_11
# 19  0.038733              month_12
# 20  0.129898    mintemperature_reg
# 21  0.213975    maxtemperature_reg
# 22  0.068390       cloudamount_reg
# 23  0.077825  weathersituation_reg
# ########################################################
# 0.653797656569

# %% [markdown]
# #### BayesianRidge

# %%
clf_br = linear_model.BayesianRidge()
params = {'alpha_1':[1e-10,1e-11,1e-12,1e-09], 'alpha_2':[1e-09,1e-08],
       'lambda_1':[1e-08,1e-06,1e-05,1e-04], 'lambda_2':[1e-12,1e-13], 
          'n_iter':[300,600,1000],
        'tol':[0.001,0.00001,0.0001,0.01], 'verbose':[False]}
clf_br.fit(Xtrain,ytrain)
clf_br, Xtrain, ytrain, Xtest, ytest = do_classify(clf_br,params,X,y)
# Out:
# BEST {'n_iter': 300, 'lambda_1': 1e-05, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.01, 'alpha_1': 1e-12, 'verbose': False} 0.69550269329 [mean: 0.69550, std: 0.06692, params: {'n_iter': 300, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 300, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 1e-05, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 300, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.0001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 300, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.01, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 600, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 600, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 1e-05, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 600, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.0001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 600, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.01, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 1000, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 1000, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 1e-05, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 1000, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.0001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 1000, 'lambda_1': 1e-08, 'lambda_2': 1e-12, 'alpha_2': 1e-09, 'tol': 0.01, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 300, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 300, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 1e-05, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 300, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.0001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 300, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.01, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 600, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 600, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 1e-05, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 600, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.0001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 600, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.01, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 1000, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 1000, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 1e-05, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 1000, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.0001, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.69550, std: 0.06692, params: {'n_iter': 1000, 'lambda_1': 1e-08, 'lambda_2': 1e-13, 'alpha_2': 1e-09, 'tol': 0.01, 'alpha_1': 1e-10, 'verbose': False}, mean: 0.695 ...
# ############# based on standard predict ################
# Accuracy on training data: 0.77
# Accuracy on test data:     0.66
# ########################################################
# no feature_importance
# ########################################################

# %% [markdown]
# #### Linear regression

# %%
clf_lr = LinearRegression()
clf_lr.fit(Xtrain,ytrain)
clf_lr.score(Xtest,ytest)
# Out:
# 0.61688078697151905

# %% [markdown]
# #### Lasso

# %%
clf_lasso = linear_model.Lasso(alpha=0.1)
params = {'alpha': [0.000001,0.0001,0.001,0.01,0.1,1,10,20,30,40,100,500]}
clf_lasso, Xtrain, ytrain, Xtest, ytest = do_classify(clf_lasso,params,X,y)
# Out:
# BEST {'alpha': 100} 0.714590638436 [mean: 0.67808, std: 0.16393, params: {'alpha': 1e-06}, mean: 0.67808, std: 0.16393, params: {'alpha': 0.0001}, mean: 0.67808, std: 0.16393, params: {'alpha': 0.001}, mean: 0.67809, std: 0.16393, params: {'alpha': 0.01}, mean: 0.67825, std: 0.16395, params: {'alpha': 0.1}, mean: 0.67985, std: 0.16412, params: {'alpha': 1}, mean: 0.69373, std: 0.16521, params: {'alpha': 10}, mean: 0.70382, std: 0.16629, params: {'alpha': 20}, mean: 0.71042, std: 0.16783, params: {'alpha': 30}, mean: 0.71458, std: 0.16859, params: {'alpha': 40}, mean: 0.71459, std: 0.16567, params: {'alpha': 100}, mean: 0.56187, std: 0.11851, params: {'alpha': 500}]
# ############# based on standard predict ################
# Accuracy on training data: 0.75
# Accuracy on test data:     0.66
# ########################################################
# no feature_importance
# ########################################################

# %% [markdown]
# #### SGD Regressor

# %%
clf_sgd = linear_model.SGDRegressor()
params = {'alpha':[0.000001,0.0001,0.001,0.01,0.1,1,10,20,30,40,100,500]}
clf_sgd, Xtrain, ytrain, Xtest, ytest = do_classify(clf_sgd,params,X,y)
# Out:
# BEST {'alpha': 0.0001} 0.213679933825 [mean: 0.20124, std: 0.07659, params: {'alpha': 1e-06}, mean: 0.21368, std: 0.06847, params: {'alpha': 0.0001}, mean: 0.21310, std: 0.07139, params: {'alpha': 0.001}, mean: 0.20645, std: 0.07271, params: {'alpha': 0.01}, mean: 0.18939, std: 0.07359, params: {'alpha': 0.1}, mean: 0.01208, std: 0.09165, params: {'alpha': 1}, mean: -0.14437, std: 0.09596, params: {'alpha': 10}, mean: -0.14990, std: 0.09600, params: {'alpha': 20}, mean: -0.14211, std: 0.08233, params: {'alpha': 30}, mean: -0.15543, std: 0.09579, params: {'alpha': 40}, mean: -0.14561, std: 0.09132, params: {'alpha': 100}, mean: -0.14733, std: 0.09440, params: {'alpha': 500}]
# ############# based on standard predict ################
# Accuracy on training data: 0.32
# Accuracy on test data:     0.30
# ########################################################
# no feature_importance
# ########################################################

# %% [markdown]
# #### TPOT Predictor

# %%
training_features, testing_features, training_classes, testing_classes = train_test_split(X[:,3:],y[:,2:].ravel(), random_state=42)

exported_pipeline = make_pipeline(
    MaxAbsScaler(),
    make_union(VotingClassifier([("est", LassoLarsCV(normalize=False))]), FunctionTransformer(lambda X: X)),
    RandomForestRegressor(n_estimators=800)
)

exported_pipeline.fit(training_features, training_classes)
results = exported_pipeline.predict(testing_features)
print exported_pipeline.score(testing_features,testing_classes)
# Out:
# 0.529157122649

# %%
df_forecasts[df_forecasts.idbldsite==site].sname.values[0]
# Out:
# 'Emmen'

# %%
fig, ax = plt.subplots()
# plt.bar(df_forecasts[df_forecasts.idbldsite==site].date.values,y_forecast[:,2:],alpha=0.7,color='grey',align='center')
plt.plot(df_forecasts[df_forecasts.idbldsite==site].date.values,(clf_rdm.predict(X_forecast[:,3:])),color='b')
plt.plot(df_forecasts[df_forecasts.idbldsite==site].date.values,(clf_lasso.predict(X_forecast[:,3:])),color='green')
# plt.plot(df_forecasts[df_forecasts.idbldsite==site].date.values,(clf_sgd.predict(X_forecast[:,3:])),alpha=0.6,color='pink')
plt.plot(df_forecasts[df_forecasts.idbldsite==site].date.values,(clf_br.predict(X_forecast[:,3:])),alpha=0.6,color='yellow')
plt.plot(df_forecasts[df_forecasts.idbldsite==site].date.values,(exported_pipeline.predict(X_forecast[:,3:])),color='red')

labels = ax.get_xticklabels()
plt.setp(labels, rotation=30, fontsize=10)
ax.legend(['Randomforest','Lasso','Bayesian','Tpot'],loc=0)
# plt.title(df_forecasts[df_forecasts.idbldsite==site].sname.values[0])

# %% [markdown]
# #### Tpot

# %%
# X_train, X_test, y_train, y_test = train_test_split(X[:,3:],y[:,2:].ravel(),
#                                                     train_size=0.75, test_size=0.25)

# tpot = TPOTRegressor(generations=5, population_size=20, verbosity=2)
# tpot.fit(X_train, y_train)
# print(tpot.score(X_test, y_test))
# tpot.export('tpot_roussos_pipeline.py')
